# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # SWARM PLOTS

# %%
sns.swarmplot(x="day", y="tip",data=df)
sns.set_style("whitegrid")
plt.show()

# %%
# Visualization tip observations
sns.swarmplot(x=df["tip"])
sns.set_style("darkgrid")
plt.show()

# %%
#color points by category
# create customized palette
gender_palette = ["#A833FF","#FFAF33"]
sns.swarmplot(x="day",y="tip",hue="sex",palette=gender_palette,data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# control plot order on x-axis
sns.swarmplot(x="smoker",y="total_bill",data=df,palette="husl",order =["Yes","No"])
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_9168\3000939532.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="smoker",y="total_bill",data=df,palette="husl",order =["Yes","No"])

# %% [markdown]
# # VIOLIN PLOTS

# %%
# PLOT TIPS
sns.violinplot(x=df["tip"], color = "gold")
plt.show()

# %%
# draw a plot based on variable
sns.violinplot(x="sex", y="total_bill", data=df)
plt.show()

# %%
# split drawings to compare with hue/legend variables
sns.violinplot(x = "time", y = "tip", data = df, hue = "sex", palette = "dark", split = True)
plt.legend()
plt.show()

# %%
sns.violinplot(x = "time", y = "tip", data = df, hue = "sex", palette = "dark" )
plt.legend()
plt.show()

# %% [markdown]
# # FACET GRIDS

# %%
fg = sns.FacetGrid(df,col = "time", row = "sex")
fg = fg.map(plt.hist,"tip", color = "tomato")

# %%
# we can also change the type of plot and the colors around the plot
fg = sns.FacetGrid(df, col = "time", row = "sex")
fg = fg.map(plt.scatter, "total_bill", "tip", color = "floralwhite", edgecolor = "hotpink")

# %%
# plot by category
x = sns.FacetGrid(df, col = "time", hue = "sex")
x = x.map(plt.scatter, "total_bill", "tip")
x = x.add_legend()

# %% [markdown]
# # HEAT MAP

# %%
# create random data
uniform_data = np.random.rand(5, 3)
print(uniform_data)
sns.heatmap(uniform_data)
plt.show()
# Out:
# [[0.48245853 0.87207906 0.4732068 ]
#  [0.5971379  0.24755363 0.51816737]
#  [0.34406439 0.30913229 0.99694627]
#  [0.5003813  0.27744468 0.86165939]
#  [0.57188852 0.19294871 0.8472258 ]]

# %%
# Flight Dataset
# load fight dataset
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.head()
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights = flights.pivot("month", "year", "passengers")
x = sns.heatmap(flights, linewidth=0.3)
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_9168\1278327413.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month", "year", "passengers")

# %%
# change color and add value
x = sns.heatmap(flights, annot = True, fmt="d", cmap="YlGnBu")
